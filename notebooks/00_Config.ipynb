# %% [markdown]
# # Brake Cycle Detection — Configuration
#
# This notebook defines all shared constants. Every other notebook imports it via `%run ./00_Config`.
#
# ## Before You Run
#
# ### 1. Cluster Requirements
#
# | Setting | Value |
# |---------|-------|
# | **Databricks Runtime** | 15.4 LTS ML or later |
# | **Node type** | Single node (e.g. `i3.xlarge`) is sufficient for the demo |
# | **Unity Catalog** | Must be enabled on the workspace |
#
# ### 2. What You Need to Change
#
# Update the **three variables** below to match your environment:
#
# | Variable | What to set | Example |
# |----------|-------------|--------|
# | `CATALOG` | Your Unity Catalog catalog name | `my_catalog` |
# | `SCHEMA` | Schema (database) to create tables in | `cycle_detection` |
# | `EXPERIMENT_NAME` | MLflow experiment path (use your username) | `/Users/you@company.com/cycle-detection` |
#
# You need `CREATE CATALOG`, `CREATE SCHEMA`, and `USE CATALOG` permissions on the catalog.
#
# ### 3. Run Order
#
# Run the notebooks in order: `00` → `01` → `02` → `03` → `04`.

# %%
# ============================================================
# >>> CHANGE THESE THREE VALUES TO MATCH YOUR ENVIRONMENT <<<
# ============================================================
CATALOG = "your_catalog"              # your Unity Catalog catalog
SCHEMA = "cycle_detection"        # schema to store all tables
EXPERIMENT_NAME = "/Users/your.email@company.com/cycle-detection"  # MLflow experiment path

# ============================================================
# Derived names — no need to change anything below
# ============================================================
RAW_SENSOR_TABLE = f"{CATALOG}.{SCHEMA}.raw_sensor_data"
FEATURE_TABLE = f"{CATALOG}.{SCHEMA}.cycle_detection_features"
CYCLE_RESULTS_TABLE = f"{CATALOG}.{SCHEMA}.detected_cycles"
PREDICTIONS_TABLE = f"{CATALOG}.{SCHEMA}.cycle_predictions"
MODEL_NAME = f"{CATALOG}.{SCHEMA}.cycle_detection_model"

print(f"Catalog:           {CATALOG}")
print(f"Schema:            {SCHEMA}")
print(f"Raw sensor table:  {RAW_SENSOR_TABLE}")
print(f"Feature table:     {FEATURE_TABLE}")
print(f"Predictions table: {PREDICTIONS_TABLE}")
print(f"Cycles table:      {CYCLE_RESULTS_TABLE}")
print(f"Model name:        {MODEL_NAME}")
print(f"MLflow experiment:  {EXPERIMENT_NAME}")
